# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

# Matplotlib Theme
mpl.rcParams.update({
    'font.family': 'DejaVu Sans',
    'axes.titlesize': 18,
    'axes.labelsize': 15,
    'xtick.labelsize': 13,
    'ytick.labelsize': 13,
    'legend.fontsize': 13,
    'axes.facecolor': '#f5f5f2', 
    'figure.facecolor': '#f5f5f2',
    'axes.edgecolor': '#444444',
    'xtick.color': '#444444',
    'ytick.color': '#444444',
    'grid.color': '#bbbbbb',
    'axes.spines.top': False,
    'axes.spines.right': False
})

# Load Data
file_path = r"C:\Users\murra\Downloads\M1_ROI_50KProb_2025-07-18(Sheet1).csv"
df = pd.read_csv(file_path)
df["X1"] = pd.to_numeric(df["X1"], errors="coerce")
df["Y1"] = pd.to_numeric(df["Y1"], errors="coerce")
df = df.dropna(subset=["X1", "Y1"])
df = df.sort_values(by="X1")

# Thresholds and Stats
threshold_0 = 0
threshold_15k = 15000
min_val = df["X1"].min()
max_val = df["X1"].max()

# Plot
fig, ax = plt.subplots(figsize=(12, 7))
ax.plot(df["X1"], df["Y1"], color='#1f77b4', linewidth=3, label="Cumulative Probability")
ax.tick_params(axis='both', colors='black')

# Fill areas
ax.fill_between(df["X1"], 0, df["Y1"], where=(df["X1"] <= threshold_0), color='gray', alpha=0.2, label="ROI ≤ $0")
ax.fill_between(df["X1"], 0, df["Y1"], where=(df["X1"] > threshold_0), color='#1f77b4', alpha=0.2, label="ROI > $0")

# Threshold line
ax.axvline(threshold_15k, color='green', linestyle='--', linewidth=1.5)

# Text Annotations
ax.text(threshold_0 - 70000, 0.985, '0.5%', fontsize=15, ha='center', color='black', bbox=dict(facecolor='white', edgecolor='gray', boxstyle='round,pad=0.3'))
ax.text(threshold_15k + 185000, 0.985, '95.5%', fontsize=15, ha='center', color='black', bbox=dict(facecolor='white', edgecolor='gray', boxstyle='round,pad=0.3'))
ax.text(threshold_15k + 10000, 0.58, '$15K Threshold', color='green', fontsize=15, ha='left', va='bottom', bbox=dict(facecolor='white', edgecolor='gray', boxstyle='round,pad=0.3'))

# Axis labels
ax.set_xlabel("ROI ($)", labelpad=10)

# Grid and Legend
ax.grid(True, linewidth=1, alpha=1)
legend = ax.legend(loc='lower right', frameon=True, facecolor='white', edgecolor='gray', framealpha=1, borderpad=1, labelspacing=0.8, bbox_to_anchor=(1, 0.05))
legend.get_frame().set_boxstyle('round,pad=0.4')

ax.set_xlim(min_val - 50000, max_val + 50000)
ax.set_ylim(0, 1.05)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

# Matplotlib styling
mpl.rcParams.update({
    'font.family': 'DejaVu Sans',
    'axes.titlesize': 18,
    'axes.labelsize': 15,
    'xtick.labelsize': 13,
    'ytick.labelsize': 13,
    'legend.fontsize': 13,
    'axes.facecolor': '#f5f5f2',
    'figure.facecolor': '#f5f5f2',
    'axes.edgecolor': '#444444',
    'xtick.color': '#444444',
    'ytick.color': '#444444',
    'grid.color': '#bbbbbb',
    'axes.spines.top': False,
    'axes.spines.right': False
})

# Load and clean data
file_path = r"C:\Users\murra\Downloads\M1_ROI_50KProb_2025-07-18(Sheet1).csv"
df = pd.read_csv(file_path)
df["X1"] = pd.to_numeric(df["X1"], errors="coerce")
df["Y1"] = pd.to_numeric(df["Y1"], errors="coerce")
df = df.dropna(subset=["X1", "Y1"])
df = df.sort_values(by="X1")

# Thresholds
threshold_0 = 0
threshold_50k = 50000
min_val = df["X1"].min()
max_val = df["X1"].max()

# Plot setup
fig, ax = plt.subplots(figsize=(12, 7))
ax.plot(df["X1"], df["Y1"], color='#1f77b4', linewidth=3, label="Cumulative Probability")
ax.tick_params(axis='both', colors='black')

# Fill areas
ax.fill_between(df["X1"], 0, df["Y1"], where=(df["X1"] <= threshold_0), color='gray', alpha=0.2, label="ROI ≤ $0")
ax.fill_between(df["X1"], 0, df["Y1"], where=(df["X1"] > threshold_0), color='#1f77b4', alpha=0.2, label="ROI > $0")

# Threshold line
ax.axvline(threshold_50k, color='green', linestyle='--', linewidth=1.5)

# Annotations
ax.text(threshold_50k + 9900, 0.58, '$50K Threshold', ha='left', fontsize=15, color='green', bbox=dict(facecolor='white', edgecolor='gray', boxstyle='round,pad=0.3'))

# Show % chance <=0 and >= 50K
ax.text(threshold_0 - 25000, 0.985, '10.3%', fontsize=15, ha='center', color='black', bbox=dict(facecolor='white', edgecolor='gray', boxstyle='round,pad=0.3'))
ax.text(threshold_50k + 250000, 0.985, '89.7%', fontsize=15, ha='center', color='black', bbox=dict(facecolor='white', edgecolor='gray', boxstyle='round,pad=0.3'))


# Labels and grid
ax.set_xlabel("ROI ($)", labelpad=10)
ax.grid(True, linewidth=1, alpha=1)
legend = ax.legend(loc='lower right', frameon=True, facecolor='white', edgecolor='gray', framealpha=1, borderpad=1, labelspacing=0.8, bbox_to_anchor=(1, 0.05))
legend.get_frame().set_boxstyle('round,pad=0.4')

ax.set_xlim(min_val - 50000, max_val + 50000)
ax.set_ylim(0, 1.05)

plt.tight_layout()
plt.show()
